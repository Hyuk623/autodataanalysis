# %% [markdown]
# # Automated EDA example
# This notebook demonstrates running the analysis engine on a small synthetic dataset.

# %%
import pandas as pd
from sklearn.datasets import make_regression
from app import analysis_engine

X, y = make_regression(n_samples=50, n_features=3, noise=0.1, random_state=0)
df = pd.DataFrame(X, columns=['x1', 'x2', 'x3'])
df['target'] = y

result = analysis_engine.run_analysis(df, explicit_target='target')
result['problem_type'], list(result['analysis_summary'].keys())
